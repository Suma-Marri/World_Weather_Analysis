# %%
# Import dependencies
import pandas as pd
import numpy as np
from citipy import citipy
import sys
sys.path.append('..')
from config import weather_api_key
import requests

# %%
# Create set of 2,000 latitudes and longitudes
lats = np.random.uniform(-90, 90, 2000)
lngs = np.random.uniform(-180, 180, 2000)
coords = list(zip(lats,lngs))

# %%
# Initialize cities list
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coord in coords:
    city = citipy.nearest_city(coord[0], coord[1]).city_name
    country = citipy.nearest_city(coord[0], coord[1]).country_code
    
    # If the city is unique, then we will add it to the cities list.
    if (city,country) not in cities:
        cities.append((city,country))

# %%
# Check the number of cities
len(cities)
# Out:
# 736

# %%
# base url for OWM calls
base_url = "http://api.openweathermap.org/data/2.5/weather"

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count+=1
        record_count = 1
    # Create parameters.
    params = {"q": city, "units": "Imperial", "APPID": weather_api_key}
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of the Set {set_count} | {city[0]}")
    
    # Add 1 to the record count.
    record_count+=1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(base_url, params=params).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_desc = str(city_weather["weather"][0]["description"])
        # Append the city information into city_data list.
        city_data.append({
            "City": city[0].title(),
            "Lat": city_lat,
            "Lng": city_lng,
            "Max Temp": city_max_temp,
            "Humidity": city_humidity,
            "Cloudiness": city_clouds,
            "Wind Speed": city_wind,
            "Country": city_country,
            "Current Description": city_weather_desc})
    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of the Set 1 | dubrovka
# Processing Record 2 of the Set 1 | saint-philippe
# Processing Record 3 of the Set 1 | cape town
# Processing Record 4 of the Set 1 | chuy
# Processing Record 5 of the Set 1 | elmira
# Processing Record 6 of the Set 1 | mount isa
# Processing Record 7 of the Set 1 | jamestown
# Processing Record 8 of the Set 1 | ust-kulom
# Processing Record 9 of the Set 1 | wangqing
# Processing Record 10 of the Set 1 | dikson
# Processing Record 11 of the Set 1 | port keats
# Processing Record 12 of the Set 1 | katsuura
# Processing Record 13 of the Set 1 | lavrentiya
# Processing Record 14 of the Set 1 | andenes
# Processing Record 15 of the Set 1 | iqaluit
# Processing Record 16 of the Set 1 | lubao
# Processing Record 17 of the Set 1 | lagoa
# Processing Record 18 of the Set 1 | lorengau
# Processing Record 19 of the Set 1 | chabahar
# Processing Record 20 of the Set 1 | mataura
# Processing Record 21 of the Set 1 | tuktoyaktuk
# Processing Record 22 of the Set 1 | belushya guba
# Processing Record 23 of the Set 1 | aswan
# Processing Record 24 of the Set 1 | juba
# Processing Record 25 of the Set 1 | mahebourg
# Processing Record 26 of the Set 1 | punta arenas
# Processing Record 27 of the Set 1 | itarema
# Processing Record 28 of the Set 1 | tyukalinsk
# Processing Record 29 of the Set 1 | grindavik
# Processing Record 30 of the Set 1 | ambon
# Processing Record 31 of the Set 1 | reconquista
# Processing Record 32 of the Set 1 | yellowknife
# Processing Record 33 of the Set 1 | hilo
# Processing Record 34 of the Set 1 | puerto ayora
# Processing Record 35 of the Set 1 | new norfolk
# Processing Record 36 of the Set 1 | butaritari
# Processing Record 37 of the Set 1 | severo-kurilsk
# Processing Record 38 of the Set 1 | albany
# Processing Record 39 of the Set 1 | verkhnyaya inta
# Processing Record 40 of the Set 1 | xinyu
# Processing Record 41 of the Set 1 | kapaa
# Processing Record 42 of the Set 1 | chokurdakh
# Processing Record 43 of the Set 1 | hithadhoo
# Processing Record 44 of the Set 1 | orlik
# Processing Record 45 of the Set 1 | busselton
# Processing Record 46 of the Set 1 | mar del plata
# Processing Record 47 of the Set 1 | fredericksburg
# Processing Record 48 of the Set 1 | wexford
# Processing Record 49 of the Set 1 | hobart
# Processing Record 50 of the Set 1 | ormond beach
# Processing Record 1 of the Set 2 | rikitea
# Processing Record 2 of the Set 2 | ancud
# Processing Record 3 of the Set 2 | ishige
# Processing Record 4 of the Set 2 | tabiauea
# Processing Record 5 of the Set 2 | vaini
# Processing Record 6 of the Set 2 | norman wells
# Processing Record 7 of the Set 2 | bluff
# Processing Record 8 of the Set 2 | vieques
# Processing Record 9 of the Set 2 | fairbanks
# Processing Record 10 of the Set 2 | torbay
# Processing Record 11 of the Set 2 | teahupoo
# Processing Record 12 of the Set 2 | georgetown
# Processing Record 13 of the Set 2 | avarua
# Processing Record 14 of the Set 2 | lewisporte
# Processing Record 15 of the Set 2 | qaanaaq
# Processing Record 16 of the Set 2 | kamaishi
# Processing Record 17 of the Set 2 | taltal
# Processing Record 18 of the Set 2 | taoudenni
# Processing Record 19 of the Set 2 | bethel
# Processing Record 20 of the Set 2 | hermanus
# Processing Record 21 of the Set 2 | luderitz
# Processing Record 22 of the Set 2 | port elizabeth
# Processing Record 23 of the Set 2 | yialos
# City not found. Skipping...
# Processing Record 24 of the Set 2 | bac lieu
# Processing Record 25 of the Set 2 | itapeva
# Processing Record 26 of the Set 2 | nikolskoye
# Processing Record 27 of the Set 2 | east london
# Processing Record 28 of the Set 2 | tanshui
# City not found. Skipping...
# Processing Record 29 of the Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 30 of the Set 2 | kieta
# Processing Record 31 of the Set 2 | lisakovsk
# Processing Record 32 of the Set 2 | nizhneyansk
# Processing Record 33 of the Set 2 | san jeronimo de tunan
# City not found. Skipping...
# Processing Record 34 of the Set 2 | saldanha
# Processing Record 35 of the Set 2 | juifang
# City not found. Skipping...
# Processing Record 36 of the Set 2 | tooele
# Processing Record 37 of the Set 2 | yomitan
# Processing Record 38 of the Set 2 | hervey bay
# Processing Record 39 of the Set 2 | atuona
# Processing Record 40 of the Set 2 | la ronge
# Processing Record 41 of the Set 2 | tono
# Processing Record 42 of the Set 2 | llanes
# Processing Record 43 of the Set 2 | ushuaia
# Processing Record 44 of the Set 2 | bredasdorp
# Processing Record 45 of the Set 2 | ribnitz-damgarten
# Processing Record 46 of the Set 2 | khonuu
# Processing Record 47 of the Set 2 | westport
# Processing Record 48 of the Set 2 | sao joao batista
# Processing Record 49 of the Set 2 | narsaq
# Processing Record 50 of the Set 2 | mana
# Processing Record 1 of the Set 3 | cidreira
# Processing Record 2 of the Set 3 | cayenne
# Processing Record 3 of the Set 3 | port alfred
# Processing Record 4 of the Set 3 | sadasivpet
# Processing Record 5 of the Set 3 | half moon bay
# Processing Record 6 of the Set 3 | dunedin
# Processing Record 7 of the Set 3 | talara
# City not found. Skipping...
# Processing Record 8 of the Set 3 | zhangjiakou
# Processing Record 9 of the Set 3 | baghdad
# Processing Record 10 of the Set 3 | ribeira grande
# Processing Record 11 of the Set 3 | ponta do sol
# Processing Record 12 of the Set 3 | cabo san lucas
# Processing Record 13 of the Set 3 | cherskiy
# Processing Record 14 of the Set 3 | sentyabrskiy
# Processing Record 15 of the Set 3 | yenangyaung
# Processing Record 16 of the Set 3 | yumen
# Processing Record 17 of the Set 3 | kahului
# Processing Record 18 of the Set 3 | illoqqortoormiut
# Processing Record 19 of the Set 3 | formosa
# Processing Record 20 of the Set 3 | fremont
# Processing Record 21 of the Set 3 | gorkovskoye
# Processing Record 22 of the Set 3 | dingle
# Processing Record 23 of the Set 3 | aklavik
# Processing Record 24 of the Set 3 | aykhal
# Processing Record 25 of the Set 3 | patillas
# Processing Record 26 of the Set 3 | wolfenbuttel
# Processing Record 27 of the Set 3 | palencia
# Processing Record 28 of the Set 3 | ostrovnoy
# Processing Record 29 of the Set 3 | saint george
# Processing Record 30 of the Set 3 | virginia beach
# Processing Record 31 of the Set 3 | kodiak
# Processing Record 32 of the Set 3 | saraland
# Processing Record 33 of the Set 3 | leh
# Processing Record 34 of the Set 3 | khandyga
# Processing Record 35 of the Set 3 | vao
# Processing Record 36 of the Set 3 | anjar
# Processing Record 37 of the Set 3 | sabang
# Processing Record 38 of the Set 3 | okmulgee
# Processing Record 39 of the Set 3 | barrow
# Processing Record 40 of the Set 3 | ordu
# Processing Record 41 of the Set 3 | lebu
# Processing Record 42 of the Set 3 | vaitape
# Processing Record 43 of the Set 3 | carlisle
# Processing Record 44 of the Set 3 | tiksi
# Processing Record 45 of the Set 3 | morondava
# City not found. Skipping...
# Processing Record 46 of the Set 3 | lompoc
# Processing Record 47 of the Set 3 | caravelas
# Processing Record 48 of the Set 3 | sao joao da barra
# Processing Record 49 of the Set 3 | lulea
# Processing Record 50 of the Set 3 | victoria
# Processing Record 1 of the Set 4 | samusu
# City not found. Skipping...
# Processing Record 2 of the Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 3 of the Set 4 | port hawkesbury
# Processing Record 4 of the Set 4 | pevek
# Processing Record 5 of the Set 4 | port lincoln
# Processing Record 6 of the Set 4 | mys shmidta
# Processing Record 7 of the Set 4 | baykit
# Processing Record 8 of the Set 4 | karratha
# Processing Record 9 of the Set 4 | longyearbyen
# Processing Record 10 of the Set 4 | guarapari
# Processing Record 11 of the Set 4 | temiscaming
# Processing Record 12 of the Set 4 | hay river
# Processing Record 13 of the Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 14 of the Set 4 | ilebo
# Processing Record 15 of the Set 4 | sao filipe
# Processing Record 16 of the Set 4 | marathon
# Processing Record 17 of the Set 4 | vrangel
# Processing Record 18 of the Set 4 | castro
# Processing Record 19 of the Set 4 | tasiilaq
# Processing Record 20 of the Set 4 | nuuk
# Processing Record 21 of the Set 4 | codrington
# Processing Record 22 of the Set 4 | coihaique
# Processing Record 23 of the Set 4 | bengkulu
# Processing Record 24 of the Set 4 | thompson
# Processing Record 25 of the Set 4 | pyay
# Processing Record 26 of the Set 4 | coquimbo
# Processing Record 27 of the Set 4 | novo aripuana
# Processing Record 28 of the Set 4 | almeirim
# Processing Record 29 of the Set 4 | laguna
# Processing Record 30 of the Set 4 | touros
# Processing Record 31 of the Set 4 | kropotkin
# Processing Record 32 of the Set 4 | oranjemund
# Processing Record 33 of the Set 4 | pisco
# City not found. Skipping...
# Processing Record 34 of the Set 4 | little current
# Processing Record 35 of the Set 4 | halalo
# City not found. Skipping...
# Processing Record 36 of the Set 4 | lerwick
# Processing Record 37 of the Set 4 | airai
# Processing Record 38 of the Set 4 | barentsburg
# Processing Record 39 of the Set 4 | chikwawa
# Processing Record 40 of the Set 4 | san policarpo
# Processing Record 41 of the Set 4 | rockport
# Processing Record 42 of the Set 4 | tarapur
# Processing Record 43 of the Set 4 | port-cartier
# Processing Record 44 of the Set 4 | bonavista
# Processing Record 45 of the Set 4 | vila franca do campo
# Processing Record 46 of the Set 4 | one hundred mile house
# Processing Record 47 of the Set 4 | tiznit
# Processing Record 48 of the Set 4 | chernenko
# Processing Record 49 of the Set 4 | arraial do cabo
# Processing Record 50 of the Set 4 | tuatapere
# Processing Record 1 of the Set 5 | tallahassee
# Processing Record 2 of the Set 5 | saint anthony
# Processing Record 3 of the Set 5 | belogorsk
# Processing Record 4 of the Set 5 | prokopyevsk
# Processing Record 5 of the Set 5 | phangnga
# Processing Record 6 of the Set 5 | berlevag
# Processing Record 7 of the Set 5 | pacific grove
# Processing Record 8 of the Set 5 | road town
# Processing Record 9 of the Set 5 | hobyo
# Processing Record 10 of the Set 5 | geraldton
# Processing Record 11 of the Set 5 | necochea
# Processing Record 12 of the Set 5 | constitucion
# Processing Record 13 of the Set 5 | tura
# Processing Record 14 of the Set 5 | dudinka
# Processing Record 15 of the Set 5 | pedernales
# Processing Record 16 of the Set 5 | emilio carranza
# Processing Record 17 of the Set 5 | sumbawa
# Processing Record 18 of the Set 5 | purranque
# Processing Record 19 of the Set 5 | sabya
# Processing Record 20 of the Set 5 | bandarbeyla
# Processing Record 21 of the Set 5 | lampang
# Processing Record 22 of the Set 5 | saskylakh
# Processing Record 23 of the Set 5 | saleaula
# City not found. Skipping...
# Processing Record 24 of the Set 5 | biak
# Processing Record 25 of the Set 5 | hasaki
# Processing Record 26 of the Set 5 | totskoye
# Processing Record 27 of the Set 5 | richards bay
# Processing Record 28 of the Set 5 | attawapiskat
# Processing Record 29 of the Set 5 | noyabrsk
# Processing Record 30 of the Set 5 | grafton
# Processing Record 31 of the Set 5 | riverton
# Processing Record 32 of the Set 5 | woodward
# Processing Record 33 of the Set 5 | champerico
# Processing Record 34 of the Set 5 | thongwa
# Processing Record 35 of the Set 5 | hearst
# Processing Record 36 of the Set 5 | porto novo
# Processing Record 37 of the Set 5 | mayumba
# Processing Record 38 of the Set 5 | warri
# Processing Record 39 of the Set 5 | superior
# Processing Record 40 of the Set 5 | prince rupert
# Processing Record 41 of the Set 5 | huambo
# Processing Record 42 of the Set 5 | souillac
# Processing Record 43 of the Set 5 | tumannyy
# Processing Record 44 of the Set 5 | sakaiminato
# Processing Record 45 of the Set 5 | umzimvubu
# Processing Record 46 of the Set 5 | chissamba
# Processing Record 47 of the Set 5 | terra boa
# Processing Record 48 of the Set 5 | kavieng
# Processing Record 49 of the Set 5 | rawannawi
# Processing Record 50 of the Set 5 | the valley
# Processing Record 1 of the Set 6 | tezu
# Processing Record 2 of the Set 6 | falmouth
# Processing Record 3 of the Set 6 | ust-shonosha
# Processing Record 4 of the Set 6 | iskateley
# Processing Record 5 of the Set 6 | kamina
# Processing Record 6 of the Set 6 | vila velha
# Processing Record 7 of the Set 6 | sumbe
# Processing Record 8 of the Set 6 | broome
# Processing Record 9 of the Set 6 | nome
# Processing Record 10 of the Set 6 | lata
# Processing Record 11 of the Set 6 | srivardhan
# Processing Record 12 of the Set 6 | asau
# Processing Record 13 of the Set 6 | micheweni
# Processing Record 14 of the Set 6 | mitsamiouli
# Processing Record 15 of the Set 6 | provideniya
# Processing Record 16 of the Set 6 | camacha
# Processing Record 17 of the Set 6 | tessalit
# Processing Record 18 of the Set 6 | zhezkazgan
# Processing Record 19 of the Set 6 | bukama
# Processing Record 20 of the Set 6 | gobabis
# Processing Record 21 of the Set 6 | kavaratti
# Processing Record 22 of the Set 6 | talaya
# Processing Record 23 of the Set 6 | antrim
# Processing Record 24 of the Set 6 | livenka
# Processing Record 25 of the Set 6 | kaeo
# Processing Record 26 of the Set 6 | ilulissat
# Processing Record 27 of the Set 6 | ballina
# Processing Record 28 of the Set 6 | talanga
# Processing Record 29 of the Set 6 | san patricio
# Processing Record 30 of the Set 6 | talnakh
# Processing Record 31 of the Set 6 | khatanga
# Processing Record 32 of the Set 6 | french harbor
# Processing Record 33 of the Set 6 | waipawa
# Processing Record 34 of the Set 6 | phuthaditjhaba
# Processing Record 35 of the Set 6 | mozarlandia
# Processing Record 36 of the Set 6 | natchitoches
# Processing Record 37 of the Set 6 | axim
# Processing Record 38 of the Set 6 | ekhabi
# Processing Record 39 of the Set 6 | haibowan
# Processing Record 40 of the Set 6 | auki
# Processing Record 41 of the Set 6 | turka
# Processing Record 42 of the Set 6 | padang
# Processing Record 43 of the Set 6 | cabedelo
# Processing Record 44 of the Set 6 | nouadhibou
# Processing Record 45 of the Set 6 | burica
# City not found. Skipping...
# Processing Record 46 of the Set 6 | bambous virieux
# Processing Record 47 of the Set 6 | malwan
# Processing Record 48 of the Set 6 | bathsheba
# Processing Record 49 of the Set 6 | harper
# Processing Record 50 of the Set 6 | peniche
# Processing Record 1 of the Set 7 | jiuquan
# Processing Record 2 of the Set 7 | neiafu
# Processing Record 3 of the Set 7 | esperance
# Processing Record 4 of the Set 7 | carnarvon
# Processing Record 5 of the Set 7 | port blair
# Processing Record 6 of the Set 7 | amderma
# Processing Record 7 of the Set 7 | avila
# Processing Record 8 of the Set 7 | ahipara
# Processing Record 9 of the Set 7 | upernavik
# Processing Record 10 of the Set 7 | majene
# Processing Record 11 of the Set 7 | yerbogachen
# Processing Record 12 of the Set 7 | sechura
# City not found. Skipping...
# Processing Record 13 of the Set 7 | tobermory
# Processing Record 14 of the Set 7 | verkhniy baskunchak
# Processing Record 15 of the Set 7 | hamilton
# Processing Record 16 of the Set 7 | husavik
# Processing Record 17 of the Set 7 | qaqortoq
# Processing Record 18 of the Set 7 | alta floresta
# Processing Record 19 of the Set 7 | te anau
# Processing Record 20 of the Set 7 | varkkallai
# Processing Record 21 of the Set 7 | lydenburg
# Processing Record 22 of the Set 7 | yuma
# Processing Record 23 of the Set 7 | saint-die
# City not found. Skipping...
# Processing Record 24 of the Set 7 | senneterre
# Processing Record 25 of the Set 7 | kelowna
# Processing Record 26 of the Set 7 | santa eulalia del rio
# Processing Record 27 of the Set 7 | puri
# Processing Record 28 of the Set 7 | cockburn town
# Processing Record 29 of the Set 7 | oksfjord
# Processing Record 30 of the Set 7 | cotonou
# Processing Record 31 of the Set 7 | mayo
# Processing Record 32 of the Set 7 | loa janan
# Processing Record 33 of the Set 7 | araouane
# Processing Record 34 of the Set 7 | nivala
# Processing Record 35 of the Set 7 | barbar
# Processing Record 36 of the Set 7 | venado tuerto
# Processing Record 37 of the Set 7 | malanje
# Processing Record 38 of the Set 7 | skelleftea
# Processing Record 39 of the Set 7 | kamenskoye
# Processing Record 40 of the Set 7 | xinmin
# Processing Record 41 of the Set 7 | marivan
# Processing Record 42 of the Set 7 | mirabad
# Processing Record 43 of the Set 7 | grand river south east
# Processing Record 44 of the Set 7 | kaitangata
# Processing Record 45 of the Set 7 | camana
# City not found. Skipping...
# Processing Record 46 of the Set 7 | shamkhal-termen
# Processing Record 47 of the Set 7 | vadso
# Processing Record 48 of the Set 7 | temirtau
# Processing Record 49 of the Set 7 | salalah
# Processing Record 50 of the Set 7 | takhtamygda
# Processing Record 1 of the Set 8 | rawah
# Processing Record 2 of the Set 8 | asyut
# Processing Record 3 of the Set 8 | marcona
# City not found. Skipping...
# Processing Record 4 of the Set 8 | zyryanka
# Processing Record 5 of the Set 8 | sarankhola
# Processing Record 6 of the Set 8 | clyde river
# Processing Record 7 of the Set 8 | ankazoabo
# City not found. Skipping...
# Processing Record 8 of the Set 8 | tagusao
# Processing Record 9 of the Set 8 | geraldton
# Processing Record 10 of the Set 8 | gorontalo
# Processing Record 11 of the Set 8 | vanimo
# Processing Record 12 of the Set 8 | gamba
# Processing Record 13 of the Set 8 | isangel
# Processing Record 14 of the Set 8 | lakatoro
# Processing Record 15 of the Set 8 | gurskoye
# Processing Record 16 of the Set 8 | moron
# Processing Record 17 of the Set 8 | ulagan
# Processing Record 18 of the Set 8 | solnechnyy
# Processing Record 19 of the Set 8 | redmond
# Processing Record 20 of the Set 8 | morehead
# Processing Record 21 of the Set 8 | senanga
# Processing Record 22 of the Set 8 | coahuayana
# Processing Record 23 of the Set 8 | warrnambool
# Processing Record 24 of the Set 8 | cocobeach
# Processing Record 25 of the Set 8 | nsanje
# Processing Record 26 of the Set 8 | mujiayingzi
# Processing Record 27 of the Set 8 | raudeberg
# Processing Record 28 of the Set 8 | walvis bay
# Processing Record 29 of the Set 8 | jiroft
# Processing Record 30 of the Set 8 | pasighat
# Processing Record 31 of the Set 8 | campina verde
# Processing Record 32 of the Set 8 | raymond
# Processing Record 33 of the Set 8 | kenora
# Processing Record 34 of the Set 8 | mergui
# Processing Record 35 of the Set 8 | great yarmouth
# Processing Record 36 of the Set 8 | vardo
# Processing Record 37 of the Set 8 | saint-francois
# Processing Record 38 of the Set 8 | longmont
# Processing Record 39 of the Set 8 | college
# Processing Record 40 of the Set 8 | mpika
# Processing Record 41 of the Set 8 | bonthe
# Processing Record 42 of the Set 8 | sukhaya buyvola
# Processing Record 43 of the Set 8 | bitung
# Processing Record 44 of the Set 8 | sakakah
# Processing Record 45 of the Set 8 | oistins
# Processing Record 46 of the Set 8 | saint andrews
# Processing Record 47 of the Set 8 | adana
# Processing Record 48 of the Set 8 | sinnamary
# Processing Record 49 of the Set 8 | honiara
# Processing Record 50 of the Set 8 | altonia
# Processing Record 1 of the Set 9 | makokou
# Processing Record 2 of the Set 9 | aleksandro-nevskiy
# Processing Record 3 of the Set 9 | namibe
# Processing Record 4 of the Set 9 | gat
# Processing Record 5 of the Set 9 | manono
# Processing Record 6 of the Set 9 | puerto del rosario
# Processing Record 7 of the Set 9 | plettenberg bay
# Processing Record 8 of the Set 9 | koslan
# Processing Record 9 of the Set 9 | comodoro rivadavia
# Processing Record 10 of the Set 9 | westport
# Processing Record 11 of the Set 9 | kushiro
# Processing Record 12 of the Set 9 | vestmannaeyjar
# Processing Record 13 of the Set 9 | canutama
# Processing Record 14 of the Set 9 | ocampo
# Processing Record 15 of the Set 9 | bur gabo
# Processing Record 16 of the Set 9 | nepa nagar
# Processing Record 17 of the Set 9 | boyolangu
# Processing Record 18 of the Set 9 | coos bay
# Processing Record 19 of the Set 9 | purificacion
# Processing Record 20 of the Set 9 | saint-pierre
# Processing Record 21 of the Set 9 | belyy yar
# Processing Record 22 of the Set 9 | matinhos
# Processing Record 23 of the Set 9 | barra do garcas
# Processing Record 24 of the Set 9 | harrisburg
# Processing Record 25 of the Set 9 | burley
# Processing Record 26 of the Set 9 | tuysarkan
# Processing Record 27 of the Set 9 | dhidhdhoo
# Processing Record 28 of the Set 9 | grand gaube
# Processing Record 29 of the Set 9 | aripuana
# Processing Record 30 of the Set 9 | broken hill
# Processing Record 31 of the Set 9 | keti bandar
# Processing Record 32 of the Set 9 | arrifes
# Processing Record 33 of the Set 9 | banda aceh
# Processing Record 34 of the Set 9 | huarmey
# City not found. Skipping...
# Processing Record 35 of the Set 9 | rondonopolis
# Processing Record 36 of the Set 9 | hun
# Processing Record 37 of the Set 9 | misratah
# Processing Record 38 of the Set 9 | ejido
# Processing Record 39 of the Set 9 | salta
# Processing Record 40 of the Set 9 | atar
# Processing Record 41 of the Set 9 | haapiti
# Processing Record 42 of the Set 9 | vodyane
# Processing Record 43 of the Set 9 | ponta do sol
# Processing Record 44 of the Set 9 | sao joao de pirabas
# Processing Record 45 of the Set 9 | egvekinot
# Processing Record 46 of the Set 9 | nanortalik
# Processing Record 47 of the Set 9 | warrington
# Processing Record 48 of the Set 9 | guozhen
# Processing Record 49 of the Set 9 | una
# Processing Record 50 of the Set 9 | brae
# Processing Record 1 of the Set 10 | port-gentil
# Processing Record 2 of the Set 10 | sitka
# Processing Record 3 of the Set 10 | sergiyevsk
# Processing Record 4 of the Set 10 | medvedka
# Processing Record 5 of the Set 10 | burnie
# Processing Record 6 of the Set 10 | hofn
# Processing Record 7 of the Set 10 | xuanzhou
# Processing Record 8 of the Set 10 | alotau
# Processing Record 9 of the Set 10 | jacareacanga
# Processing Record 10 of the Set 10 | yeppoon
# Processing Record 11 of the Set 10 | chapais
# Processing Record 12 of the Set 10 | buckeye
# Processing Record 13 of the Set 10 | pangnirtung
# Processing Record 14 of the Set 10 | yaan
# Processing Record 15 of the Set 10 | faanui
# Processing Record 16 of the Set 10 | borogontsy
# Processing Record 17 of the Set 10 | atambua
# Processing Record 18 of the Set 10 | guane
# Processing Record 19 of the Set 10 | lufilufi
# City not found. Skipping...
# Processing Record 20 of the Set 10 | ganzhou
# Processing Record 21 of the Set 10 | vahan
# Processing Record 22 of the Set 10 | lima
# City not found. Skipping...
# Processing Record 23 of the Set 10 | sao miguel do araguaia
# Processing Record 24 of the Set 10 | kaberamaido
# Processing Record 25 of the Set 10 | ingham
# Processing Record 26 of the Set 10 | ixtapa
# Processing Record 27 of the Set 10 | wajid
# Processing Record 28 of the Set 10 | hecun
# Processing Record 29 of the Set 10 | vostochnyy
# Processing Record 30 of the Set 10 | vila
# Processing Record 31 of the Set 10 | nizhnyaya tavda
# Processing Record 32 of the Set 10 | beberibe
# Processing Record 33 of the Set 10 | meyungs
# Processing Record 34 of the Set 10 | naliya
# Processing Record 35 of the Set 10 | hovd
# Processing Record 36 of the Set 10 | banyumas
# Processing Record 37 of the Set 10 | gilgit
# Processing Record 38 of the Set 10 | lasa
# Processing Record 39 of the Set 10 | sataua
# City not found. Skipping...
# Processing Record 40 of the Set 10 | magistralnyy
# Processing Record 41 of the Set 10 | sur
# Processing Record 42 of the Set 10 | ambulu
# Processing Record 43 of the Set 10 | arlit
# Processing Record 44 of the Set 10 | cumana
# Processing Record 45 of the Set 10 | tocopilla
# Processing Record 46 of the Set 10 | dutse
# Processing Record 47 of the Set 10 | idritsa
# Processing Record 48 of the Set 10 | solovetskiy
# Processing Record 49 of the Set 10 | port hardy
# Processing Record 50 of the Set 10 | zolochiv
# Processing Record 1 of the Set 11 | samarai
# Processing Record 2 of the Set 11 | yirol
# Processing Record 3 of the Set 11 | la estancia
# Processing Record 4 of the Set 11 | alofi
# Processing Record 5 of the Set 11 | ondo
# Processing Record 6 of the Set 11 | baker city
# Processing Record 7 of the Set 11 | boke
# Processing Record 8 of the Set 11 | bereda
# Processing Record 9 of the Set 11 | aasiaat
# Processing Record 10 of the Set 11 | porto empedocle
# Processing Record 11 of the Set 11 | port moresby
# Processing Record 12 of the Set 11 | chase
# Processing Record 13 of the Set 11 | limbang
# Processing Record 14 of the Set 11 | igarka
# Processing Record 15 of the Set 11 | batemans bay
# Processing Record 16 of the Set 11 | linjiang
# Processing Record 17 of the Set 11 | matara
# Processing Record 18 of the Set 11 | nizwa
# Processing Record 19 of the Set 11 | sorland
# Processing Record 20 of the Set 11 | yar-sale
# Processing Record 21 of the Set 11 | wanning
# Processing Record 22 of the Set 11 | cervo
# Processing Record 23 of the Set 11 | betul
# Processing Record 24 of the Set 11 | cagliliog
# Processing Record 25 of the Set 11 | cananeia
# Processing Record 26 of the Set 11 | misawa
# Processing Record 27 of the Set 11 | paamiut
# Processing Record 28 of the Set 11 | la paz
# Processing Record 29 of the Set 11 | elbrus
# Processing Record 30 of the Set 11 | seoul
# Processing Record 31 of the Set 11 | nyrob
# Processing Record 32 of the Set 11 | piacabucu
# Processing Record 33 of the Set 11 | izumo
# Processing Record 34 of the Set 11 | hirado
# Processing Record 35 of the Set 11 | deputatskiy
# Processing Record 36 of the Set 11 | chagda
# Processing Record 37 of the Set 11 | labytnangi
# Processing Record 38 of the Set 11 | lanigan
# Processing Record 39 of the Set 11 | alappuzha
# Processing Record 40 of the Set 11 | maarianhamina
# Processing Record 41 of the Set 11 | tucupita
# Processing Record 42 of the Set 11 | missoula
# Processing Record 43 of the Set 11 | omboue
# Processing Record 44 of the Set 11 | fort nelson
# Processing Record 45 of the Set 11 | taksimo
# Processing Record 46 of the Set 11 | bay roberts
# Processing Record 47 of the Set 11 | abonnema
# Processing Record 48 of the Set 11 | canmore
# Processing Record 49 of the Set 11 | san cristobal
# Processing Record 50 of the Set 11 | santa maria
# Processing Record 1 of the Set 12 | margate
# Processing Record 2 of the Set 12 | kruisfontein
# Processing Record 3 of the Set 12 | olinda
# Processing Record 4 of the Set 12 | sibi
# Processing Record 5 of the Set 12 | kerouane
# Processing Record 6 of the Set 12 | eureka
# Processing Record 7 of the Set 12 | olafsvik
# Processing Record 8 of the Set 12 | horasan
# Processing Record 9 of the Set 12 | santo estevao
# Processing Record 10 of the Set 12 | gaillac
# City not found. Skipping...
# Processing Record 11 of the Set 12 | labutta
# Processing Record 12 of the Set 12 | kem
# Processing Record 13 of the Set 12 | ramnagar
# Processing Record 14 of the Set 12 | arco
# Processing Record 15 of the Set 12 | novoagansk
# Processing Record 16 of the Set 12 | rosario
# Processing Record 17 of the Set 12 | arman
# Processing Record 18 of the Set 12 | kenai
# Processing Record 19 of the Set 12 | gbarnga
# Processing Record 20 of the Set 12 | osa
# Processing Record 21 of the Set 12 | palabuhanratu
# Processing Record 22 of the Set 12 | skagastrond
# Processing Record 23 of the Set 12 | nieuw amsterdam
# Processing Record 24 of the Set 12 | wajir
# Processing Record 25 of the Set 12 | urumqi
# Processing Record 26 of the Set 12 | roma
# Processing Record 27 of the Set 12 | wamba
# Processing Record 28 of the Set 12 | carnduff
# Processing Record 29 of the Set 12 | marawi
# Processing Record 30 of the Set 12 | buraydah
# Processing Record 31 of the Set 12 | pochutla
# Processing Record 32 of the Set 12 | shimoda
# Processing Record 33 of the Set 12 | leningradskiy
# Processing Record 34 of the Set 12 | jutai
# Processing Record 35 of the Set 12 | temaraia
# Processing Record 36 of the Set 12 | klyuchi
# Processing Record 37 of the Set 12 | aporawan
# Processing Record 38 of the Set 12 | taylorville
# Processing Record 39 of the Set 12 | sawtell
# Processing Record 40 of the Set 12 | bestobe
# Processing Record 41 of the Set 12 | shishou
# Processing Record 42 of the Set 12 | usoke
# Processing Record 43 of the Set 12 | teguldet
# Processing Record 44 of the Set 12 | qandahar
# Processing Record 45 of the Set 12 | moses lake
# Processing Record 46 of the Set 12 | chamalieres
# City not found. Skipping...
# Processing Record 47 of the Set 12 | barawe
# Processing Record 48 of the Set 12 | plopeni
# Processing Record 49 of the Set 12 | nhulunbuy
# Processing Record 50 of the Set 12 | east wenatchee bench
# Processing Record 1 of the Set 13 | aranda de duero
# Processing Record 2 of the Set 13 | bolungarvik
# Processing Record 3 of the Set 13 | balabac
# Processing Record 4 of the Set 13 | istok
# Processing Record 5 of the Set 13 | longlac
# Processing Record 6 of the Set 13 | bilibino
# Processing Record 7 of the Set 13 | rolim de moura
# Processing Record 8 of the Set 13 | quatre cocos
# Processing Record 9 of the Set 13 | mosquera
# Processing Record 10 of the Set 13 | gorno-chuyskiy
# Processing Record 11 of the Set 13 | waddan
# Processing Record 12 of the Set 13 | kisangani
# Processing Record 13 of the Set 13 | carutapera
# Processing Record 14 of the Set 13 | krasnyy oktyabr
# Processing Record 15 of the Set 13 | ahuimanu
# Processing Record 16 of the Set 13 | miracema do tocantins
# Processing Record 17 of the Set 13 | mandurah
# Processing Record 18 of the Set 13 | port hedland
# Processing Record 19 of the Set 13 | ekuvukeni
# Processing Record 20 of the Set 13 | poum
# Processing Record 21 of the Set 13 | shitanjing
# Processing Record 22 of the Set 13 | radolfzell
# Processing Record 23 of the Set 13 | mizpe ramon
# City not found. Skipping...
# Processing Record 24 of the Set 13 | nargana
# City not found. Skipping...
# Processing Record 25 of the Set 13 | baffa
# Processing Record 26 of the Set 13 | jalu
# Processing Record 27 of the Set 13 | kangaatsiaq
# Processing Record 28 of the Set 13 | shar
# Processing Record 29 of the Set 13 | licata
# Processing Record 30 of the Set 13 | zhongshu
# Processing Record 31 of the Set 13 | opuwo
# Processing Record 32 of the Set 13 | teya
# Processing Record 33 of the Set 13 | aden
# Processing Record 34 of the Set 13 | beruni
# City not found. Skipping...
# Processing Record 35 of the Set 13 | havoysund
# Processing Record 36 of the Set 13 | waiouru
# Processing Record 37 of the Set 13 | sacapulas
# Processing Record 38 of the Set 13 | bairiki
# Processing Record 39 of the Set 13 | dubovyy umet
# Processing Record 40 of the Set 13 | kargil
# Processing Record 41 of the Set 13 | acapulco
# Processing Record 42 of the Set 13 | gushikawa
# Processing Record 43 of the Set 13 | singkang
# Processing Record 44 of the Set 13 | george town
# Processing Record 45 of the Set 13 | milkovo
# Processing Record 46 of the Set 13 | katherine
# Processing Record 47 of the Set 13 | namatanai
# Processing Record 48 of the Set 13 | kununurra
# Processing Record 49 of the Set 13 | san carlos del zulia
# Processing Record 50 of the Set 13 | meulaboh
# Processing Record 1 of the Set 14 | steenbergen
# Processing Record 2 of the Set 14 | klaksvik
# Processing Record 3 of the Set 14 | excelsior springs
# Processing Record 4 of the Set 14 | port augusta
# Processing Record 5 of the Set 14 | rokytne
# Processing Record 6 of the Set 14 | palana
# Processing Record 7 of the Set 14 | bose
# Processing Record 8 of the Set 14 | abu dhabi
# Processing Record 9 of the Set 14 | dezhou
# Processing Record 10 of the Set 14 | blaj
# Processing Record 11 of the Set 14 | tarhunah
# Processing Record 12 of the Set 14 | mareeba
# Processing Record 13 of the Set 14 | brandon
# Processing Record 14 of the Set 14 | guekedou
# Processing Record 15 of the Set 14 | griffith
# Processing Record 16 of the Set 14 | dubreuil
# Processing Record 17 of the Set 14 | warqla
# City not found. Skipping...
# Processing Record 18 of the Set 14 | hirara
# Processing Record 19 of the Set 14 | samaniego
# Processing Record 20 of the Set 14 | zhigansk
# Processing Record 21 of the Set 14 | bela
# Processing Record 22 of the Set 14 | oktyabrskoye
# Processing Record 23 of the Set 14 | kamenka
# Processing Record 24 of the Set 14 | charters towers
# Processing Record 25 of the Set 14 | abha
# Processing Record 26 of the Set 14 | sobolevo
# Processing Record 27 of the Set 14 | cuamba
# Processing Record 28 of the Set 14 | niquelandia
# Processing Record 29 of the Set 14 | abu kamal
# Processing Record 30 of the Set 14 | chiredzi
# Processing Record 31 of the Set 14 | amapa
# Processing Record 32 of the Set 14 | ngukurr
# Processing Record 33 of the Set 14 | lanxi
# Processing Record 34 of the Set 14 | esna
# Processing Record 35 of the Set 14 | quelimane
# Processing Record 36 of the Set 14 | saint-augustin
# Processing Record 37 of the Set 14 | voskresenskoye
# Processing Record 38 of the Set 14 | mayenne
# City not found. Skipping...
# Processing Record 39 of the Set 14 | nantucket
# Processing Record 40 of the Set 14 | clearwater
# Processing Record 41 of the Set 14 | flin flon
# Processing Record 42 of the Set 14 | lakes entrance
# Processing Record 43 of the Set 14 | chinhoyi
# Processing Record 44 of the Set 14 | kusa
# Processing Record 45 of the Set 14 | dzaoudzi
# Processing Record 46 of the Set 14 | hudiksvall
# Processing Record 47 of the Set 14 | itoman
# Processing Record 48 of the Set 14 | truro
# Processing Record 49 of the Set 14 | katav-ivanovsk
# Processing Record 50 of the Set 14 | macamic
# Processing Record 1 of the Set 15 | sao felix do xingu
# Processing Record 2 of the Set 15 | fasa
# Processing Record 3 of the Set 15 | takoradi
# Processing Record 4 of the Set 15 | bauchi
# Processing Record 5 of the Set 15 | bardiyah
# Processing Record 6 of the Set 15 | bodo
# Processing Record 7 of the Set 15 | tautira
# Processing Record 8 of the Set 15 | paragominas
# Processing Record 9 of the Set 15 | dickinson
# Processing Record 10 of the Set 15 | mitu
# Processing Record 11 of the Set 15 | quang ngai
# Processing Record 12 of the Set 15 | sao domingos
# Processing Record 13 of the Set 15 | toppenish
# Processing Record 14 of the Set 15 | ca mau
# Processing Record 15 of the Set 15 | thatta
# Processing Record 16 of the Set 15 | kamyshla
# Processing Record 17 of the Set 15 | puerto baquerizo moreno
# Processing Record 18 of the Set 15 | karaton
# Processing Record 19 of the Set 15 | kloulklubed
# Processing Record 20 of the Set 15 | velikovechnoye
# Processing Record 21 of the Set 15 | adre
# Processing Record 22 of the Set 15 | marienburg
# Processing Record 23 of the Set 15 | port macquarie
# Processing Record 24 of the Set 15 | xining
# Processing Record 25 of the Set 15 | xiaoweizhai
# Processing Record 26 of the Set 15 | mishkino
# Processing Record 27 of the Set 15 | camabatela
# Processing Record 28 of the Set 15 | ritchie
# Processing Record 29 of the Set 15 | mahibadhoo
# Processing Record 30 of the Set 15 | sakata
# Processing Record 31 of the Set 15 | maniitsoq
# Processing Record 32 of the Set 15 | amposta
# Processing Record 33 of the Set 15 | turayf
# Processing Record 34 of the Set 15 | grimari
# City not found. Skipping...
# Processing Record 35 of the Set 15 | guerrero negro
# Processing Record 36 of the Set 15 | tarata
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Add data to a new DataFrame
cities_weather_df = pd.DataFrame(city_data)
# Reorder the columns
cities_weather_df=cities_weather_df[["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]]
cities_weather_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Dubrovka      RU  53.6907   33.5071     15.78        96         100
# 1  Saint-Philippe      RE -21.3585   55.7679     72.99        72          95
# 2       Cape Town      ZA -33.9258   18.4232     68.41        76           0
# 3            Chuy      UY -33.6971  -53.4616     75.67        93         100
# 4          Elmira      US  42.0898  -76.8077     23.00        58          20
# 5       Mount Isa      AU -20.7333  139.5000     82.17        83          40
# 6       Jamestown      US  42.0970  -79.2353     18.72        85         100
# 7       Ust-Kulom      RU  53.6907   33.5071     15.78        96         100
# 8        Wangqing      CN  43.3218  129.7634      8.94        90          39
# 9          Dikson      RU  53.6907   33.5071     15.78        96         100
#
#    Wind Speed Current Description
# 0        4.74                snow
# 1       12.93          light rain
# 2        7.00           clear sky
# 3        6.55       moderate rain
# 4        6.91          few clouds
# 5       11.50    scattered clouds
# 6        8.05     overcast clouds
# 7        4.74                snow
# 8        1.88    scattered clouds
# 9        4.74                snow

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the dataframe to csv
cities_weather_df.to_csv(output_data_file, index_label="City_ID")
